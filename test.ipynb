# %%
import pandas as pd
import numpy as np

# %%
test = np.load("imu_data_raw.npy")

# %%
print(test)
# Out:
# NpzFile 'imu_data_raw.npy' with keys: Node[1].XL1.X, Node[1].XL1.timestamp, Node[1].XL1.interval_id, Node[1].XL1.Y, Node[1].XL1.Z...
